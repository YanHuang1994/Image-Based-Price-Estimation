# %%
import os
import math
import pandas as pd
from PIL import Image
import pickle
import random
import warnings
from collections import OrderedDict

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import torchvision.datasets as dset
import torchvision.transforms as T
from torchvision import models
from torch.utils.data import DataLoader, sampler, random_split
warnings.filterwarnings("ignore")

# %%
def fix_random_seed(seed_no=0):
    torch.manual_seed(seed_no)
    torch.cuda.manual_seed(seed_no)
    random.seed(seed_no)

# %%
# read the guitar info
df = pd.read_csv("D:/Study Abroad/course/CSE498/project/guitar_info.csv")

# %%
# load the valid guitar image indice
train_data_id = []
file_path = "D:/Study Abroad/course/CSE498/project/guitar_resized_images"

# walk through all guitar images
for root, dirs, files in os.walk(file_path):
    for file in files:
        train_data_id.append(int(file.replace(".png","")))

# %%
# select guitar info for valid images
df = df[df['index'].isin(train_data_id)]
df['price'] = df['price'].apply(lambda x:math.ceil(float(x.replace("$","").replace(",",""))))

# %%
df
# Out:
#           index                                              image  \
# 2     119748013  https://media.guitarcenter.com/is/image/MMGS7/...
# 3     119744391  https://media.guitarcenter.com/is/image/MMGS7/...
# 4     119746162  https://media.guitarcenter.com/is/image/MMGS7/...
# 5     119739399  https://media.guitarcenter.com/is/image/MMGS7/...
# 7     119744853  https://media.guitarcenter.com/is/image/MMGS7/...
# ...         ...                                                ...
# 4194  119740084  https://media.guitarcenter.com/is/image/MMGS7/...
# 4195  119742274  https://media.guitarcenter.com/is/image/MMGS7/...
# 4196  119744806  https://media.guitarcenter.com/is/image/MMGS7/...
# 4197  119739960  https://media.guitarcenter.com/is/image/MMGS7/...
# 4198  119734771  https://media.guitarcenter.com/is/image/MMGS7/...
#
#                                                   title             location  \
# 2            Used Carvin AC375 Acoustic Electric Guitar       N. Olmsted, OH
# 3           Used Martin GPC16E Acoustic Electric Guitar          Danbury, CT
# 4     Used Gibson JERRY CANTRELL ATONE SONGWRITER Ac...       N. Olmsted, OH
# 5     Used Taylor 214CE Deluxe Acoustic Electric Guitar          Raleigh, NC
# 7          Used PRS Angelus Standard SE Acoustic Guitar       Allen Park, MI
# ...                                                 ...                  ...
# 4194         Used Taylor 514CE Acoustic Electric Guitar        Allentown, PA
# 4195    Used Mitchell Mx430qab Acoustic Electric Guitar       Manchester, CT
# 4196  Used Gibson J45 Standard Acoustic Electric Guitar        Bridgeton, MO
# 4197                 Used Yamaha FG-280 Acoustic Guitar      Monroeville, PA
# 4198   Used Taylor 214e-SB DLX Acoustic Electric Guitar  Hickory Corners, NC
#
#       price  condition
# 2       925  Excellent
# 3      1640  Excellent
# 4      3500  Excellent
# 5      1300  Excellent
# 7       575  Excellent
# ...     ...        ...
# 4194   1500      Great
# 4195    270      Great
# 4196   2300      Great
# 4197    400      Great
# 4198   1100      Great
#
# [3046 rows x 6 columns]

# %%
# calculate the mean and std of R, G, and B channels for my guitar image data sets
path = "D:/Study Abroad/course/CSE498/project/guitar_resized_images"

# define a tensor transformer
image_transformer = T.ToTensor()

def normal_para(path, transformer):
    tensors = []
    # walk through all images and convert them to tensors
    for index in df['index'].values:
        file_name = '000000'+str(index) + '.png'
        file_path = os.path.join(path,file_name)
        image = Image.open(file_path)
        tensor = transformer(image)
        tensors.append(tensor)

    # stack all tensors into a single tensor
    tensor_stack = torch.stack(tensors, dim=0)

    # calculate the mean and std
    mean = torch.mean(tensor_stack, dim=[0, 2, 3])
    std = torch.std(tensor_stack, dim=[0, 2, 3])
    
    return mean,std

# calculate the mean and std of R, G, and B channels
mean,std = normal_para(path, image_transformer)

# %%
# define a class to generate training, validation, and testing set
class Guitar_Image_Data_Set:
    """ this class is designed to generate training, validation, and testing set from guitar images"""
    def __init__(self,dataframe,path,transform):
        self.df = dataframe
        self.path = path
        self.tf = transform
        
    def __len__(self):
        return self.df.shape[0]
    
    def __getitem__(self,idx):
        file_name = '000000'+ str(df.iloc[idx]['index']) + '.png'
        file_path = os.path.join(self.path,file_name)
        image = Image.open(file_path)
        image = self.tf(image)
        price = df.iloc[idx]['price']
        
        return image, price

# %%
# transform images to tensors and then normalize tensors
transform = T.Compose([
            T.ToTensor(),
            T.Normalize(mean, std)
            ])

# create an instance of the Dataset
guitar_dataset = Guitar_Image_Data_Set(dataframe = df,
                                       path = path,
                                       transform = transform)

# define the ratio for training, validation, and testing set
total = len(guitar_dataset)
train = 0.7
validation = 0.15

# split the whole dataset into training, validation, and testing set
train_size = int(train * total)
validation_size = int(validation * total)
test_size = total - train_size - validation_size
train_dataset, validation_dataset, test_dataset = random_split(guitar_dataset, [train_size, validation_size, test_size])

# %%
# Use DataLoader to batch and shuffle the dataset
loader_train = DataLoader(train_dataset, batch_size=64,shuffle = True)
loader_val = DataLoader(validation_dataset, batch_size=64,shuffle = True)
loader_test = DataLoader(test_dataset, batch_size=64,shuffle = True)

# %%
# define the configuration of torch
dtype = torch.float

gpu_index = torch.randint(0, torch.cuda.device_count(), (1,)).item()
device = torch.device('cuda:{}'.format(gpu_index))
print("PyTorch is using GPU {}!".format(device))

# Constant to control how frequently we print train loss
print_every = 100
# Out:
# PyTorch is using GPU cuda:0!

# %%
# define a function that returns a consistent, predetermined random number
def fix_random_seed(seed_no=0):
    torch.manual_seed(seed_no)
    torch.cuda.manual_seed(seed_no)
    random.seed(seed_no)

# define functions for adjusting learning rate
def adjust_learning_rate(optimizer, lrd, epoch, schedule):
    """
    Multiply lrd to the learning rate if epoch is in schedule

    Inputs:
    - optimizer: An Optimizer object we will use to train the model
    - lrd: learning rate decay; a factor multiplied at scheduled epochs
    - epochs: the current epoch number
    - schedule: the list of epochs that requires learning rate update

    Returns: Nothing, but learning rate might be updated
    """
    if epoch in schedule:
        for param_group in optimizer.param_groups:
            print('lr decay from {} to {}'.format(param_group['lr'], param_group['lr'] * lrd))
            param_group['lr'] *= lrd

# define functions for training the model
def train_model(model, optimizer, epochs=1, learning_rate_decay=.1, schedule=[], criterion = nn.MSELoss()):
    """
    Train a model on guitar image dataset using the PyTorch Module API.

    Inputs:
    - model: A PyTorch Module giving the model to train.
    - optimizer: An Optimizer object we will use to train the model
    - epochs: (Optional) A Python integer giving the number of epochs to train for

    Returns: Nothing, but prints model accuracies during training.
    """
    
    num_iters = epochs * len(loader_train)
    num_prints = num_iters // print_every + 1

    for e in range(epochs):
        
        adjust_learning_rate(optimizer, learning_rate_decay, e, schedule)

        for t, (x, y) in enumerate(loader_train):
            model.train()  # put model to training mode
            x = x.to(device=device, dtype=dtype)  # move to device, e.g. GPU
            y = y.to(device=device, dtype=dtype)
            outputs = model(x)
            
            # calculatet the loss using assigned criterion 
            loss = criterion(outputs, y.view(-1, 1))
            
            # Zero out all of the gradients for the variables which the optimizer will update.
            optimizer.zero_grad()

            # This is the backwards pass: compute the gradient of the loss with
            # respect to each  parameter of the model.
            loss.backward()

            # Actually update the parameters of the model using the gradients
            # computed by the backwards pass.
            optimizer.step()

            tt = t + e * len(loader_train)
            print('Epoch %d, Iteration %d, loss = %.0f' % (e, tt, loss.item()))

# %%
# train a toy model - a neural network with two fully connected layers
fix_random_seed(0)

C, H, W = 3, 200, 200

# initialize the output layer with 1 node for regression tasks.
output_size = 1 

hidden_layer_size = 4096
learning_rate = 1e-6
weight_decay = 1e-3
momentum = 0.5
epochs = 5

# To give a specific name to each module, use OrderedDict.
model = nn.Sequential(OrderedDict([
  ('flatten', nn.Flatten()),
  ('fc1', nn.Linear(C * H * W, hidden_layer_size)),
  ('relu1', nn.ReLU()),
  ('fc2', nn.Linear(hidden_layer_size, output_size)),
]))

model.to(device)

# use SGD as the optimizer
optimizer = optim.SGD(model.parameters(), 
                      lr=learning_rate,
                      weight_decay=weight_decay,
                      momentum=momentum,
                      nesterov=True)

# print the Architecture of the model
print('Architecture:')
print(model)
print()

# print the loss in the training process
print('Training:')
train_model(model, optimizer,epochs = epochs)
# Out:
# Architecture:
# Sequential(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (fc1): Linear(in_features=120000, out_features=4096, bias=True)
#   (relu1): ReLU()
#   (fc2): Linear(in_features=4096, out_features=1, bias=True)
# )
#
# Training:
# Epoch 0, Iteration 0, loss = 2932893
# Epoch 0, Iteration 1, loss = 1861908
# Epoch 0, Iteration 2, loss = 3294296
# Epoch 0, Iteration 3, loss = 1470952
# Epoch 0, Iteration 4, loss = 1024124
# Epoch 0, Iteration 5, loss = 1872902
# Epoch 0, Iteration 6, loss = 590646
# Epoch 0, Iteration 7, loss = 1148460
# Epoch 0, Iteration 8, loss = 7782816
# Epoch 0, Iteration 9, loss = 855826
# Epoch 0, Iteration 10, loss = 1072620
# Epoch 0, Iteration 11, loss = 1053771
# Epoch 0, Iteration 12, loss = 1222515
# Epoch 0, Iteration 13, loss = 644118
# Epoch 0, Iteration 14, loss = 549055
# Epoch 0, Iteration 15, loss = 2336090
# Epoch 0, Iteration 16, loss = 798603
# Epoch 0, Iteration 17, loss = 1007528
# Epoch 0, Iteration 18, loss = 596247
# Epoch 0, Iteration 19, loss = 778190
# Epoch 0, Iteration 20, loss = 725088
# Epoch 0, Iteration 21, loss = 772195
# Epoch 0, Iteration 22, loss = 886219
# Epoch 0, Iteration 23, loss = 749567
# Epoch 0, Iteration 24, loss = 1411166
# Epoch 0, Iteration 25, loss = 992694
# Epoch 0, Iteration 26, loss = 783676
# Epoch 0, Iteration 27, loss = 1168986
# Epoch 0, Iteration 28, loss = 3725463
# Epoch 0, Iteration 29, loss = 795714
# Epoch 0, Iteration 30, loss = 1834068
# Epoch 0, Iteration 31, loss = 1678202
# Epoch 0, Iteration 32, loss = 1140654
# Epoch 0, Iteration 33, loss = 865855
# Epoch 1, Iteration 34, loss = 1001386
# Epoch 1, Iteration 35, loss = 842335
# Epoch 1, Iteration 36, loss = 767977
# Epoch 1, Iteration 37, loss = 1368272
# Epoch 1, Iteration 38, loss = 714474
# Epoch 1, Iteration 39, loss = 1364519
# Epoch 1, Iteration 40, loss = 1051673
# Epoch 1, Iteration 41, loss = 1037699
# Epoch 1, Iteration 42, loss = 1725686
# Epoch 1, Iteration 43, loss = 999523
# Epoch 1, Iteration 44, loss = 1741302
# Epoch 1, Iteration 45, loss = 585147
# Epoch 1, Iteration 46, loss = 573347
# Epoch 1, Iteration 47, loss = 1148875
# Epoch 1, Iteration 48, loss = 801272
# Epoch 1, Iteration 49, loss = 1393972
# Epoch 1, Iteration 50, loss = 815182
# Epoch 1, Iteration 51, loss = 1412973
# Epoch 1, Iteration 52, loss = 7566468
# Epoch 1, Iteration 53, loss = 1596733
# Epoch 1, Iteration 54, loss = 1560953
# Epoch 1, Iteration 55, loss = 1052598
# Epoch 1, Iteration 56, loss = 673424
# Epoch 1, Iteration 57, loss = 1709043
# Epoch 1, Iteration 58, loss = 1371035
# Epoch 1, Iteration 59, loss = 2769947
# Epoch 1, Iteration 60, loss = 2165479
# Epoch 1, Iteration 61, loss = 462282
# Epoch 1, Iteration 62, loss = 1826950
# Epoch 1, Iteration 63, loss = 1783471
# Epoch 1, Iteration 64, loss = 1199118
# Epoch 1, Iteration 65, loss = 818943
# Epoch 1, Iteration 66, loss = 519174
# Epoch 1, Iteration 67, loss = 782906
# Epoch 2, Iteration 68, loss = 2653037
# Epoch 2, Iteration 69, loss = 1658569
# Epoch 2, Iteration 70, loss = 1791684
# Epoch 2, Iteration 71, loss = 1204375
# Epoch 2, Iteration 72, loss = 8944226
# Epoch 2, Iteration 73, loss = 996333
# Epoch 2, Iteration 74, loss = 2728466
# Epoch 2, Iteration 75, loss = 1701568
# Epoch 2, Iteration 76, loss = 2212245
# Epoch 2, Iteration 77, loss = 1857990
# Epoch 2, Iteration 78, loss = 1014243
# Epoch 2, Iteration 79, loss = 878095
# Epoch 2, Iteration 80, loss = 740348
# Epoch 2, Iteration 81, loss = 1250139
# Epoch 2, Iteration 82, loss = 619424
# Epoch 2, Iteration 83, loss = 964336
# Epoch 2, Iteration 84, loss = 925913
# Epoch 2, Iteration 85, loss = 1667387
# Epoch 2, Iteration 86, loss = 961512
# Epoch 2, Iteration 87, loss = 938701
# Epoch 2, Iteration 88, loss = 1040115
# Epoch 2, Iteration 89, loss = 929114
# Epoch 2, Iteration 90, loss = 979342
# Epoch 2, Iteration 91, loss = 1002630
# Epoch 2, Iteration 92, loss = 564571
# Epoch 2, Iteration 93, loss = 857697
# Epoch 2, Iteration 94, loss = 1836926
# Epoch 2, Iteration 95, loss = 630153
# Epoch 2, Iteration 96, loss = 644282
# Epoch 2, Iteration 97, loss = 680114
# Epoch 2, Iteration 98, loss = 3322393
# Epoch 2, Iteration 99, loss = 1284953
# Epoch 2, Iteration 100, loss = 1233412
# Epoch 2, Iteration 101, loss = 1897911
# Epoch 3, Iteration 102, loss = 2616694
# Epoch 3, Iteration 103, loss = 2492002
# Epoch 3, Iteration 104, loss = 2885519
# Epoch 3, Iteration 105, loss = 1708495
# Epoch 3, Iteration 106, loss = 2428912
# Epoch 3, Iteration 107, loss = 1711613
# Epoch 3, Iteration 108, loss = 2164759
# Epoch 3, Iteration 109, loss = 5130838
# Epoch 3, Iteration 110, loss = 1575364
# Epoch 3, Iteration 111, loss = 696558
# Epoch 3, Iteration 112, loss = 1934404
# Epoch 3, Iteration 113, loss = 1829465
# Epoch 3, Iteration 114, loss = 568487
# Epoch 3, Iteration 115, loss = 470776
# Epoch 3, Iteration 116, loss = 1181299
# Epoch 3, Iteration 117, loss = 1179352
# Epoch 3, Iteration 118, loss = 1430704
# Epoch 3, Iteration 119, loss = 880053
# Epoch 3, Iteration 120, loss = 830724
# Epoch 3, Iteration 121, loss = 1586587
# Epoch 3, Iteration 122, loss = 769640
# Epoch 3, Iteration 123, loss = 918571
# Epoch 3, Iteration 124, loss = 1044948
# Epoch 3, Iteration 125, loss = 1262342
# Epoch 3, Iteration 126, loss = 1380612
# Epoch 3, Iteration 127, loss = 711305
# Epoch 3, Iteration 128, loss = 689019
# Epoch 3, Iteration 129, loss = 7812166
# Epoch 3, Iteration 130, loss = 1697235
# Epoch 3, Iteration 131, loss = 3039902
# Epoch 3, Iteration 132, loss = 1354136
# Epoch 3, Iteration 133, loss = 596128
# Epoch 3, Iteration 134, loss = 674160
# Epoch 3, Iteration 135, loss = 913430
# Epoch 4, Iteration 136, loss = 822082
# Epoch 4, Iteration 137, loss = 1412796
# Epoch 4, Iteration 138, loss = 615353
# Epoch 4, Iteration 139, loss = 1626829
# Epoch 4, Iteration 140, loss = 7501662
# Epoch 4, Iteration 141, loss = 1153880
# Epoch 4, Iteration 142, loss = 638886
# Epoch 4, Iteration 143, loss = 2838350
# Epoch 4, Iteration 144, loss = 1736013
# Epoch 4, Iteration 145, loss = 1340000
# Epoch 4, Iteration 146, loss = 1934703
# Epoch 4, Iteration 147, loss = 636210
# Epoch 4, Iteration 148, loss = 1805949
# Epoch 4, Iteration 149, loss = 699870
# Epoch 4, Iteration 150, loss = 1308782
# Epoch 4, Iteration 151, loss = 738762
# Epoch 4, Iteration 152, loss = 747338
# Epoch 4, Iteration 153, loss = 1025746
# Epoch 4, Iteration 154, loss = 508217
# Epoch 4, Iteration 155, loss = 1736174
# Epoch 4, Iteration 156, loss = 1324928
# Epoch 4, Iteration 157, loss = 853352
# Epoch 4, Iteration 158, loss = 961565
# Epoch 4, Iteration 159, loss = 1858075
# Epoch 4, Iteration 160, loss = 1164144
# Epoch 4, Iteration 161, loss = 499171
# Epoch 4, Iteration 162, loss = 837427
# Epoch 4, Iteration 163, loss = 831605
# Epoch 4, Iteration 164, loss = 1298030
# Epoch 4, Iteration 165, loss = 1100565
# Epoch 4, Iteration 166, loss = 679246
# Epoch 4, Iteration 167, loss = 2003010
# Epoch 4, Iteration 168, loss = 941671
# Epoch 4, Iteration 169, loss = 410740

# %%
# train a baseline model - vgg16
fix_random_seed(0)

C, H, W = 3, 200, 200

# initialize the output layer with 1 node for regression tasks.
output_size = 1 

learning_rate = 1e-4
dropout_ratio = 0.1
epochs = 5

# load the vgg16 model
model = models.vgg16(pretrained=True)

# modify the classifier to fit the guitar image dataset
model.classifier = nn.Sequential(
    nn.Linear(25088, 512),  
    nn.ReLU(),
    nn.Dropout(dropout_ratio),
    nn.Linear(512, 1)  # output a single value for regression
)

model.to(device)

# use adam as the optimizer
optimizer = optim.Adam(model.parameters(), 
                       lr = learning_rate)

# print the Architecture of the model
print('Architecture:')
print(model)
print()

# print the loss in the training process
print('Training:')
train_model(model, optimizer, epochs = epochs)
# Out:
# Architecture:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.1, inplace=False)
#     (3): Linear(in_features=512, out_features=1, bias=True)
#   )
# )
#
# Training:
# Epoch 0, Iteration 0, loss = 1019865
# Epoch 0, Iteration 1, loss = 1757868
# Epoch 0, Iteration 2, loss = 2394703
# Epoch 0, Iteration 3, loss = 1480133
# Epoch 0, Iteration 4, loss = 1085707
# Epoch 0, Iteration 5, loss = 1003561
# Epoch 0, Iteration 6, loss = 1820996
# Epoch 0, Iteration 7, loss = 835699
# Epoch 0, Iteration 8, loss = 767471
# Epoch 0, Iteration 9, loss = 895544
# Epoch 0, Iteration 10, loss = 1162364
# Epoch 0, Iteration 11, loss = 2639616
# Epoch 0, Iteration 12, loss = 2635198
# Epoch 0, Iteration 13, loss = 1240924
# Epoch 0, Iteration 14, loss = 801855
# Epoch 0, Iteration 15, loss = 858743
# Epoch 0, Iteration 16, loss = 1157164
# Epoch 0, Iteration 17, loss = 763734
# Epoch 0, Iteration 18, loss = 1927920
# Epoch 0, Iteration 19, loss = 771834
# Epoch 0, Iteration 20, loss = 748085
# Epoch 0, Iteration 21, loss = 810600
# Epoch 0, Iteration 22, loss = 1021192
# Epoch 0, Iteration 23, loss = 729760
# Epoch 0, Iteration 24, loss = 817568
# Epoch 0, Iteration 25, loss = 526937
# Epoch 0, Iteration 26, loss = 2840397
# Epoch 0, Iteration 27, loss = 1666177
# Epoch 0, Iteration 28, loss = 485863
# Epoch 0, Iteration 29, loss = 1190804
# Epoch 0, Iteration 30, loss = 1352083
# Epoch 0, Iteration 31, loss = 8580985
# Epoch 0, Iteration 32, loss = 1450059
# Epoch 0, Iteration 33, loss = 559125
# Epoch 1, Iteration 34, loss = 1712378
# Epoch 1, Iteration 35, loss = 579864
# Epoch 1, Iteration 36, loss = 786400
# Epoch 1, Iteration 37, loss = 579825
# Epoch 1, Iteration 38, loss = 530228
# Epoch 1, Iteration 39, loss = 846881
# Epoch 1, Iteration 40, loss = 1695718
# Epoch 1, Iteration 41, loss = 1124885
# Epoch 1, Iteration 42, loss = 563402
# Epoch 1, Iteration 43, loss = 831364
# Epoch 1, Iteration 44, loss = 1344181
# Epoch 1, Iteration 45, loss = 1057139
# Epoch 1, Iteration 46, loss = 613040
# Epoch 1, Iteration 47, loss = 767499
# Epoch 1, Iteration 48, loss = 638483
# Epoch 1, Iteration 49, loss = 505501
# Epoch 1, Iteration 50, loss = 1556525
# Epoch 1, Iteration 51, loss = 8581492
# Epoch 1, Iteration 52, loss = 1630779
# Epoch 1, Iteration 53, loss = 837072
# Epoch 1, Iteration 54, loss = 548185
# Epoch 1, Iteration 55, loss = 774232
# Epoch 1, Iteration 56, loss = 1235644
# Epoch 1, Iteration 57, loss = 1472186
# Epoch 1, Iteration 58, loss = 497367
# Epoch 1, Iteration 59, loss = 3115302
# Epoch 1, Iteration 60, loss = 1087051
# Epoch 1, Iteration 61, loss = 1446289
# Epoch 1, Iteration 62, loss = 655721
# Epoch 1, Iteration 63, loss = 1783420
# Epoch 1, Iteration 64, loss = 521456
# Epoch 1, Iteration 65, loss = 665606
# Epoch 1, Iteration 66, loss = 832886
# Epoch 1, Iteration 67, loss = 914793
# Epoch 2, Iteration 68, loss = 978409
# Epoch 2, Iteration 69, loss = 481235
# Epoch 2, Iteration 70, loss = 7221743
# Epoch 2, Iteration 71, loss = 684880
# Epoch 2, Iteration 72, loss = 1004869
# Epoch 2, Iteration 73, loss = 839328
# Epoch 2, Iteration 74, loss = 485379
# Epoch 2, Iteration 75, loss = 1743164
# Epoch 2, Iteration 76, loss = 1175727
# Epoch 2, Iteration 77, loss = 699682
# Epoch 2, Iteration 78, loss = 631718
# Epoch 2, Iteration 79, loss = 881907
# Epoch 2, Iteration 80, loss = 3349257
# Epoch 2, Iteration 81, loss = 716455
# Epoch 2, Iteration 82, loss = 978617
# Epoch 2, Iteration 83, loss = 725550
# Epoch 2, Iteration 84, loss = 491865
# Epoch 2, Iteration 85, loss = 799231
# Epoch 2, Iteration 86, loss = 794264
# Epoch 2, Iteration 87, loss = 639365
# Epoch 2, Iteration 88, loss = 965636
# Epoch 2, Iteration 89, loss = 1641820
# Epoch 2, Iteration 90, loss = 530404
# Epoch 2, Iteration 91, loss = 797102
# Epoch 2, Iteration 92, loss = 600565
# Epoch 2, Iteration 93, loss = 977276
# Epoch 2, Iteration 94, loss = 1495894
# Epoch 2, Iteration 95, loss = 483271
# Epoch 2, Iteration 96, loss = 740534
# Epoch 2, Iteration 97, loss = 483496
# Epoch 2, Iteration 98, loss = 557714
# Epoch 2, Iteration 99, loss = 1440776
# Epoch 2, Iteration 100, loss = 543856
# Epoch 2, Iteration 101, loss = 335330
# Epoch 3, Iteration 102, loss = 719615
# Epoch 3, Iteration 103, loss = 1327146
# Epoch 3, Iteration 104, loss = 1438741
# Epoch 3, Iteration 105, loss = 483861
# Epoch 3, Iteration 106, loss = 611607
# Epoch 3, Iteration 107, loss = 710659
# Epoch 3, Iteration 108, loss = 706402
# Epoch 3, Iteration 109, loss = 297531
# Epoch 3, Iteration 110, loss = 407113
# Epoch 3, Iteration 111, loss = 7373458
# Epoch 3, Iteration 112, loss = 576965
# Epoch 3, Iteration 113, loss = 1320023
# Epoch 3, Iteration 114, loss = 1877108
# Epoch 3, Iteration 115, loss = 691896
# Epoch 3, Iteration 116, loss = 477525
# Epoch 3, Iteration 117, loss = 881718
# Epoch 3, Iteration 118, loss = 716378
# Epoch 3, Iteration 119, loss = 311426
# Epoch 3, Iteration 120, loss = 223478
# Epoch 3, Iteration 121, loss = 604552
# Epoch 3, Iteration 122, loss = 1593880
# Epoch 3, Iteration 123, loss = 356721
# Epoch 3, Iteration 124, loss = 932001
# Epoch 3, Iteration 125, loss = 316852
# Epoch 3, Iteration 126, loss = 503788
# Epoch 3, Iteration 127, loss = 449381
# Epoch 3, Iteration 128, loss = 375224
# Epoch 3, Iteration 129, loss = 629552
# Epoch 3, Iteration 130, loss = 623903
# Epoch 3, Iteration 131, loss = 336606
# Epoch 3, Iteration 132, loss = 466578
# Epoch 3, Iteration 133, loss = 364845
# Epoch 3, Iteration 134, loss = 275071
# Epoch 3, Iteration 135, loss = 296849
# Epoch 4, Iteration 136, loss = 1194047
# Epoch 4, Iteration 137, loss = 960262
# Epoch 4, Iteration 138, loss = 527733
# Epoch 4, Iteration 139, loss = 333340
# Epoch 4, Iteration 140, loss = 958156
# Epoch 4, Iteration 141, loss = 430744
# Epoch 4, Iteration 142, loss = 388500
# Epoch 4, Iteration 143, loss = 3544439
# Epoch 4, Iteration 144, loss = 1037065
# Epoch 4, Iteration 145, loss = 479998
# Epoch 4, Iteration 146, loss = 825946
# Epoch 4, Iteration 147, loss = 541589
# Epoch 4, Iteration 148, loss = 468246
# Epoch 4, Iteration 149, loss = 1304217
# Epoch 4, Iteration 150, loss = 937714
# Epoch 4, Iteration 151, loss = 467898
# Epoch 4, Iteration 152, loss = 511814
# Epoch 4, Iteration 153, loss = 677511
# Epoch 4, Iteration 154, loss = 567436
# Epoch 4, Iteration 155, loss = 249532
# Epoch 4, Iteration 156, loss = 384570
# Epoch 4, Iteration 157, loss = 272802
# Epoch 4, Iteration 158, loss = 513951
# Epoch 4, Iteration 159, loss = 243237
# Epoch 4, Iteration 160, loss = 478249
# Epoch 4, Iteration 161, loss = 283852
# Epoch 4, Iteration 162, loss = 822997
# Epoch 4, Iteration 163, loss = 663321
# Epoch 4, Iteration 164, loss = 544015
# Epoch 4, Iteration 165, loss = 279096
# Epoch 4, Iteration 166, loss = 783173
# Epoch 4, Iteration 167, loss = 657318
# Epoch 4, Iteration 168, loss = 627608
# Epoch 4, Iteration 169, loss = 326122
